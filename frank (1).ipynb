# %%
# @title Default title text
import numpy as np
z = np.arange(0,2).reshape(2,1)

s = z.shape
if s[0] == s[1]:
    print("Форма: квадратичная")
else:
    print("Форма: прямоугольная")
print("Размер матрицы")
print(s)
print("Размерность матрицы")
print(z.size)

# %%
import pandas as pd
url = 'https://raw.githubusercontent.com/akmand/datasets/main/sample_grades.csv'
dataframe = pd.read_csv(url)
print("фрейм данных")
dataframe.head(6)
# Out:
# фрейм данных
#    Student ID  Gender  Project Phase 1  Project Phase 2  Mid-Semester Test  \
# 0         101    Male            18.25             15.5                 94
# 1         102  Female            17.75             30.0                 79
# 2         103    Male             0.00              0.0                 78
# 3         104    Male            20.00             25.0                 69
# 4         105    Male            18.75             30.0                 96
# 5         106    Male            17.00             23.5                 80
#
#    Final Exam Grade
# 0        61.0    PA
# 1        62.0    PA
# 2        15.0    NN
# 3        65.0    PA
# 4        51.0    PA
# 5        59.0    PA

# %%
#2.3.3 Проделайте с получившемся из предыдущего задания фреймом данных те же действия, что и в примерах 2.2.5-2.2.7.
url = 'https://raw.githubusercontent.com/akmand/datasets/main/sample_grades.csv'
dataframe = pd.read_csv(url)
print("Вывод первых 5 строк: \n", dataframe.head(6))
#dataframe.head(6)
print("Последних 5 строк:\n", dataframe.tail(5))
#dataframe.tail(5)
print("Размер таблицы: \n", dataframe.shape)
print("Описательная стсатиска:\n", dataframe.describe())
#dataframe.describe()
print("Вывод строк от 7 до 12:\n", dataframe.iloc[7:13])
print("Вывод нового фрейма данных из студентов NN класса: \n", dataframe[dataframe['Grade'] == 'NN'].head(5))
# Out:
# Вывод первых 5 строк:
#     Student ID  Gender  Project Phase 1  Project Phase 2  Mid-Semester Test  \
# 0         101    Male            18.25             15.5                 94
# 1         102  Female            17.75             30.0                 79
# 2         103    Male             0.00              0.0                 78
# 3         104    Male            20.00             25.0                 69
# 4         105    Male            18.75             30.0                 96
# 5         106    Male            17.00             23.5                 80
#
#    Final Exam Grade
# 0        61.0    PA
# 1        62.0    PA
# 2        15.0    NN
# 3        65.0    PA
# 4        51.0    PA
# 5        59.0    PA
# Последних 5 строк:
#      Student ID  Gender  Project Phase 1  Project Phase 2  Mid-Semester Test  \
# 35         136    Male            18.50             22.0                 26
# 36         137  Female            20.00             26.0                 89
# ...

# %%
#3.3.2 Загрузить фрейм данных по ссылке:
#https://raw.githubusercontent.com/akmand/datasets/master/iris.csv.
#Необходимо выполнить нормализацию первого числового признака (sepal_length_cm) с использованием минимаксного преобразования, а второго (sepal_width_cm) с задействованием z-масштабирования.


import pandas as pd
from sklearn.preprocessing import MinMaxScaler
url = 'https://raw.githubusercontent.com/akmand/datasets/master/iris.csv'
scaler = MinMaxScaler()
dftest = pd.read_csv(url)
print("Таблица")

dftest['sepal_length_cm'] = scaler.fit_transform(dftest[['sepal_length_cm']])
df1 = dftest[['sepal_width_cm']].mean()
df2 = dftest[['sepal_width_cm']].std()
dftest[['sepal_width_cm']] = ((dftest[['sepal_width_cm']] - df1) / df2)
dftest[['sepal_length_cm', 'sepal_width_cm']].head(11)
# Out:
# Таблица
#     sepal_length_cm  sepal_width_cm
# 0          0.222222        1.028611
# 1          0.166667       -0.124540
# 2          0.111111        0.336720
# 3          0.083333        0.106090
# 4          0.194444        1.259242
# 5          0.305556        1.951133
# 6          0.083333        0.797981
# 7          0.194444        0.797981
# 8          0.027778       -0.355171
# 9          0.166667        0.106090
# 10         0.305556        1.489872

# %%
#1.3.1 Создать 8x8 матрицу и заполнить её в шахматном порядке нулями и единицами.
import numpy as np

Z = np.zeros((8, 8), dtype = int)
Z[1::2,::2] = 1
Z[::2,1::2] = 1
print("Матрица")
print(Z)

# %%
#1.3.2 Создать 5x5 матрицу со значениями в строках от 0 до 4. Для создания необходимо использовать функцию arrange.
import numpy as np

Z = np.zeros((5, 5))
Z += np.arange(5)
print("Матрица")
print(Z)

# %%
#1.3.3 Создать массив 3x3x3 со случайными значениями.
import numpy as np

Z = np.random.random((3,3,3))
print("Массив")
print(Z)

# %%
#1.3.4 Создать матрицу с 0 внутри, и 1 на границах.
import numpy as np
Z = np.ones((5,5))
Z[1:-1,1:-1] = 0
print("Матрица")
print(Z)

# %%
#1.3.5 Создайте массив и отсортируйте его по убыванию.
Z = np.random.random((5, 5))
print("Массив")
print(np.sort(Z))

# %%
#1.3.6 Создайте матрицу, выведите ее форму, размер и размерность.

z = np.arange(25).reshape(5,5)

s = z.shape
if s[0] == s[1]:
    print("Форма: квадратичная")
else:
    print("Форма: прямоугольная")
print(s)
print(z.size)

# %%
#2.3.1 Найдитe евклидово расстояние между двумя Series (точками) a и b, не используя встроенную формулу.
import pandas as pd
a = pd.Series([0, 1, 2,3, 4])
b = pd.Series([5, 6, 7, 8, 9])

answer = sum((a - b)**2)**0.5

print(answer)

# %%
#2.3.2 Найдите в Интернете ссылку на любой csv файл и сформируйте из него фрейм данных (например, коллекцию фреймов данных можно найти здесь: https://github.com/akmand/datasets).
url = 'https://raw.githubusercontent.com/akmand/datasets/main/sample_grades.csv'
dataframe = pd.read_csv(url)
dataframe.head(6)
